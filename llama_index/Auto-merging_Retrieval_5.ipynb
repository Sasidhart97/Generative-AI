# %% [markdown]
# # Lesson 4: Auto-merging Retrieval

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import utils

import os
import openai
openai.api_key = utils.get_openai_api_key()

# %%
from llama_index import SimpleDirectoryReader

documents = SimpleDirectoryReader(
    input_files=["./eBook-How-to-Build-a-Career-in-AI.pdf"]
).load_data()

# %%
print(type(documents), "\n")
print(len(documents), "\n")
print(type(documents[0]))
print(documents[0])
# Out:
# <class 'list'>
#
# 41
#
# <class 'llama_index.schema.Document'>
# Doc ID: 153d6590-049d-4951-ae0b-7063996eef57
# Text: PAGE 1Founder, DeepLearning.AICollected Insights from Andrew Ng
# How to  Build Your Career in AIA Simple Guide

# %% [markdown]
# ## Auto-merging retrieval setup

# %%
from llama_index import Document

document = Document(text="\n\n".join([doc.text for doc in documents]))

# %%
from llama_index.node_parser import HierarchicalNodeParser

# create the hierarchical node parser w/ default settings
node_parser = HierarchicalNodeParser.from_defaults(
    chunk_sizes=[2048, 512, 128]
)
# Out:
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
nodes = node_parser.get_nodes_from_documents([document])

# %%
from llama_index.node_parser import get_leaf_nodes

leaf_nodes = get_leaf_nodes(nodes)
print(leaf_nodes[30].text)
# Out:
# But this became less important as numerical linear algebra libraries matured.
# Deep learning is still an emerging technology, so when you train a neural network and the
# optimization algorithm struggles to converge, understanding the math behind gradient
# descent, momentum, and the Adam  optimization algorithm will help you make better decisions.
# Similarly, if your neural network does something funny — say, it makes bad predictions on
# images of a certain resolution, but not others — understanding the math behind neural network
# architectures puts you in a better position to figure out what to do.
# Of course, I also encourage learning driven by curiosity.

# %%
nodes_by_id = {node.node_id: node for node in nodes}

parent_node = nodes_by_id[leaf_nodes[30].parent_node.node_id]
print(parent_node.text)
# Out:
# PAGE 12Should You
# Learn Math to
# Get a Job in AI? CHAPTER 3
# LEARNING
#
# PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? It’s always nice to know more math! But there’s so much to
# learn that, realistically, it’s necessary to prioritize. Here’s how you might go about strengthening
# your math background.
# To figure out what’s important to know, I find it useful to ask what you need to know to make
# the decisions required for the work you want to do. At DeepLearning.AI, we frequently ask,
# “What does someone need to know to accomplish their goals?” The goal might be building a
# machine learning model, architecting a system, or passing a job interview.
# Understanding the math behind algorithms you use is often helpful, since it enables you to
# debug them. But the depth of knowledge that’s useful changes over time. As machine learning
# techniques mature and become more reliable and turnkey, they require less debugging, and a
# shallower understanding of the math involved may be sufficient to make them work.
# For instance, in an earlier era of machine learning, linear algebra libraries for solving linear
# systems of equations (for linear regression) were immature. I had to understand how these
# libraries worked so I could choose among different libraries and avoid numerical roundoff
# pitfalls. But this became less important as numerical linear algebra libraries matured.
# Deep learning is still an emerging technology, so when you train a neural network and the
# optimization algorithm struggles to converge, understanding the math behind gradient
# descent, momentum, and the Adam  optimization algorithm will help you make better decisions.
# Similarly, if your neural network does something funny — say, it makes bad predictions on
# images of a certain resolution, but not others — understanding the math behind neural network
# architectures puts you in a better position to figure out what to do.
# Of course, I also encourage learning driven by curiosity. If something interests you, go ahead
# and learn it regardless of how useful it might turn out to be!  Maybe this will lead to a creative
# spark or technical breakthrough.How much math do you need to know to be a machine learning engineer?

# %% [markdown]
# ### Building the index

# %%
from llama_index.llms import OpenAI

llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)

# %%
from llama_index import ServiceContext

auto_merging_context = ServiceContext.from_defaults(
    llm=llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    node_parser=node_parser,
)
# Out:
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
from llama_index import VectorStoreIndex, StorageContext

storage_context = StorageContext.from_defaults()
storage_context.docstore.add_documents(nodes)

automerging_index = VectorStoreIndex(
    leaf_nodes, storage_context=storage_context, service_context=auto_merging_context
)

automerging_index.storage_context.persist(persist_dir="./merging_index")

# %%
# This block of code is optional to check
# if an index file exist, then it will load it
# if not, it will rebuild it

import os
from llama_index import VectorStoreIndex, StorageContext, load_index_from_storage
from llama_index import load_index_from_storage

if not os.path.exists("./merging_index"):
    storage_context = StorageContext.from_defaults()
    storage_context.docstore.add_documents(nodes)

    automerging_index = VectorStoreIndex(
            leaf_nodes,
            storage_context=storage_context,
            service_context=auto_merging_context
        )

    automerging_index.storage_context.persist(persist_dir="./merging_index")
else:
    automerging_index = load_index_from_storage(
        StorageContext.from_defaults(persist_dir="./merging_index"),
        service_context=auto_merging_context
    )

# %% [markdown]
# ### Defining the retriever and running the query engine

# %%
from llama_index.indices.postprocessor import SentenceTransformerRerank
from llama_index.retrievers import AutoMergingRetriever
from llama_index.query_engine import RetrieverQueryEngine

automerging_retriever = automerging_index.as_retriever(
    similarity_top_k=12
)

retriever = AutoMergingRetriever(
    automerging_retriever, 
    automerging_index.storage_context, 
    verbose=True
)

rerank = SentenceTransformerRerank(top_n=6, model="BAAI/bge-reranker-base")

auto_merging_engine = RetrieverQueryEngine.from_args(
    automerging_retriever, node_postprocessors=[rerank]
)
# Out:
# config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/279 [00:00<?, ?B/s]

# %%
auto_merging_response = auto_merging_engine.query(
    "What is the importance of networking in AI?"
)

# %%
from llama_index.response.notebook_utils import display_response

display_response(auto_merging_response)
# Out:
# **`Final Response:`** Networking in AI is crucial as it helps individuals build a strong professional community that can provide valuable information, support, and opportunities. By connecting with others in the field, individuals can receive guidance, referrals to potential employers, and access to mentors or peers who can help them advance in their careers. Additionally, networking can lead to collaborations on projects, sharing of ideas, and continuous learning from domain experts, ultimately contributing to personal and professional growth in the AI community.

# %% [markdown]
# ## Putting it all Together

# %%
import os

from llama_index import (
    ServiceContext,
    StorageContext,
    VectorStoreIndex,
    load_index_from_storage,
)
from llama_index.node_parser import HierarchicalNodeParser
from llama_index.node_parser import get_leaf_nodes
from llama_index import StorageContext, load_index_from_storage
from llama_index.retrievers import AutoMergingRetriever
from llama_index.indices.postprocessor import SentenceTransformerRerank
from llama_index.query_engine import RetrieverQueryEngine


def build_automerging_index(
    documents,
    llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="merging_index",
    chunk_sizes=None,
):
    chunk_sizes = chunk_sizes or [2048, 512, 128]
    node_parser = HierarchicalNodeParser.from_defaults(chunk_sizes=chunk_sizes)
    nodes = node_parser.get_nodes_from_documents(documents)
    leaf_nodes = get_leaf_nodes(nodes)
    merging_context = ServiceContext.from_defaults(
        llm=llm,
        embed_model=embed_model,
    )
    storage_context = StorageContext.from_defaults()
    storage_context.docstore.add_documents(nodes)

    if not os.path.exists(save_dir):
        automerging_index = VectorStoreIndex(
            leaf_nodes, storage_context=storage_context, service_context=merging_context
        )
        automerging_index.storage_context.persist(persist_dir=save_dir)
    else:
        automerging_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=save_dir),
            service_context=merging_context,
        )
    return automerging_index


def get_automerging_query_engine(
    automerging_index,
    similarity_top_k=12,
    rerank_top_n=6,
):
    base_retriever = automerging_index.as_retriever(similarity_top_k=similarity_top_k)
    retriever = AutoMergingRetriever(
        base_retriever, automerging_index.storage_context, verbose=True
    )
    rerank = SentenceTransformerRerank(
        top_n=rerank_top_n, model="BAAI/bge-reranker-base"
    )
    auto_merging_engine = RetrieverQueryEngine.from_args(
        retriever, node_postprocessors=[rerank]
    )
    return auto_merging_engine

# %%
from llama_index.llms import OpenAI

index = build_automerging_index(
    [document],
    llm=OpenAI(model="gpt-3.5-turbo", temperature=0.1),
    save_dir="./merging_index",
)

# %%
query_engine = get_automerging_query_engine(index, similarity_top_k=6)

# %% [markdown]
# ## TruLens Evaluation

# %%
from trulens_eval import Tru

Tru().reset_database()
# Out:
# 🦑 Tru initialized with db url sqlite:///default.sqlite .
# 🛑 Secret keys may be written to the database. See the `database_redact_keys` option of `Tru` to prevent this.

# %% [markdown]
# ### Two layers

# %%
auto_merging_index_0 = build_automerging_index(
    documents,
    llm=OpenAI(model="gpt-3.5-turbo", temperature=0.1),
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="merging_index_0",
    chunk_sizes=[2048,512],
)

# %%
auto_merging_engine_0 = get_automerging_query_engine(
    auto_merging_index_0,
    similarity_top_k=12,
    rerank_top_n=6,
)

# %%
from utils import get_prebuilt_trulens_recorder

tru_recorder = get_prebuilt_trulens_recorder(
    auto_merging_engine_0,
    app_id ='app_0'
)
# Out:
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input response will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input source will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .

# %%
eval_questions = []
with open('generated_questions.text', 'r') as file:
    for line in file:
        # Remove newline character and convert to integer
        item = line.strip()
        eval_questions.append(item)

# %%
def run_evals(eval_questions, tru_recorder, query_engine):
    for question in eval_questions:
        with tru_recorder as recording:
            response = query_engine.query(question)

# %%
run_evals(eval_questions, tru_recorder, auto_merging_engine_0)
# Out:
# > Merging 1 nodes into parent node.
# > Parent node id: ef1d437c-6fc1-4fc3-95dc-9c3f8b7e0da2.
# > Parent node text: PAGE 26If you’re considering a role switch, a startup can be an easier place to do it than a big ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 700d2267-21a2-44dd-9cb3-f4e397e355ad.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8ce93215-06bf-4941-984b-04e5d94ad3cd.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9532a0e7-c127-4e5d-af3f-eb35ca427afc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 013531a0-3289-4973-820a-cd89b8338c5e.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: e2153647-6afb-465d-80d0-c29dda9d3b14.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 354d28e9-55db-4d4a-9e35-a36b9bddb07d.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0333aa7f-b496-4636-8d2c-e4e3c86fb5b5.
# > Parent node text: PAGE 19Develop a side hustle. Even if you have a full-time job, a fun project that may or may not...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ee03cd7c-146f-47e3-a043-7f362334f9d9.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 3aa7b259-a085-41e0-bc67-29f45535bd0b.
# > Parent node text: PAGE 30Finding someone to interview isn’t always easy, but many people who are in senior position...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9546ccb1-4ce4-4890-b9e3-22edbb714f56.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 800e68da-0200-45c1-b86a-28d660500db9.
# > Parent node text: PAGE 20Working on projects requires making tough choices about what to build and how to go
# about...
#
# > Merging 1 nodes into parent node.
# > Parent node id: e2153647-6afb-465d-80d0-c29dda9d3b14.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8ce93215-06bf-4941-984b-04e5d94ad3cd.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 692e1d27-12f8-4880-84a6-d7110099208a.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0333aa7f-b496-4636-8d2c-e4e3c86fb5b5.
# > Parent node text: PAGE 19Develop a side hustle. Even if you have a full-time job, a fun project that may or may not...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 354d28e9-55db-4d4a-9e35-a36b9bddb07d.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 83a7b40d-81b3-4dd8-b043-9d441f4206e7.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: c6438929-9a16-44f9-a556-73244add3fc9.
# > Parent node text: PAGE 24A Simple Framework
# for Starting Your AI
# Job SearchCHAPTER 7
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 013531a0-3289-4973-820a-cd89b8338c5e.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 800e68da-0200-45c1-b86a-28d660500db9.
# > Parent node text: PAGE 20Working on projects requires making tough choices about what to build and how to go
# about...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8a33cb0d-f0a5-4397-be98-ecde20d50e0b.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: e2153647-6afb-465d-80d0-c29dda9d3b14.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 83a7b40d-81b3-4dd8-b043-9d441f4206e7.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 354d28e9-55db-4d4a-9e35-a36b9bddb07d.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9532a0e7-c127-4e5d-af3f-eb35ca427afc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1686fb1c-f82b-4e1e-8daa-0b809f42d3f4.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 013531a0-3289-4973-820a-cd89b8338c5e.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 61b4d915-8ae8-4253-a5d0-39060d268604.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9546ccb1-4ce4-4890-b9e3-22edbb714f56.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0119e6d1-2de8-4477-b9d3-e6d98a5de8b8.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0333aa7f-b496-4636-8d2c-e4e3c86fb5b5.
# > Parent node text: PAGE 19Develop a side hustle. Even if you have a full-time job, a fun project that may or may not...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 354d28e9-55db-4d4a-9e35-a36b9bddb07d.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9532a0e7-c127-4e5d-af3f-eb35ca427afc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: e2153647-6afb-465d-80d0-c29dda9d3b14.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 61b4d915-8ae8-4253-a5d0-39060d268604.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 692e1d27-12f8-4880-84a6-d7110099208a.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8a33cb0d-f0a5-4397-be98-ecde20d50e0b.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1686fb1c-f82b-4e1e-8daa-0b809f42d3f4.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: f57d65e5-047a-4e47-86d2-fd2a34c38b17.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: ee03cd7c-146f-47e3-a043-7f362334f9d9.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 83a7b40d-81b3-4dd8-b043-9d441f4206e7.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: e4c1c474-53d9-4c64-ac6d-9514b90cc3da.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 8fc97aea-9497-4afa-8398-77a4ddd67a84.
# > Parent node text: PAGE 9In the previous chapter, I introduced three key steps for building a career in AI: learning...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 32217df0-c34e-48d1-997d-d16dd91e7e43.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 1 nodes into parent node.
# > Parent node id: cbd98ec5-191a-4d27-94e4-119caf690e0d.
# > Parent node text: PAGE 10This is a lot to learn!
# Even after you master everything on this list, I hope you’ll keep ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: e2153647-6afb-465d-80d0-c29dda9d3b14.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1686fb1c-f82b-4e1e-8daa-0b809f42d3f4.
# > Parent node text: PAGE 16Determine milestones. Once you’ve deemed a project sufficiently
# valuable, the next step i...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 2108c6c0-ab63-49a7-89d4-a2acba0c5210.
# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 83a7b40d-81b3-4dd8-b043-9d441f4206e7.
# > Parent node text: PAGE 15One of the most important skills of an AI architect is the ability to identify ideas that ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 9532a0e7-c127-4e5d-af3f-eb35ca427afc.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8a33cb0d-f0a5-4397-be98-ecde20d50e0b.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: d39b3ced-bab3-4547-8617-b509cabb7c2f.
# > Parent node text: PAGE 12Should You
# Learn Math to
# Get a Job in AI? CHAPTER 3
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: cbd98ec5-191a-4d27-94e4-119caf690e0d.
# > Parent node text: PAGE 10This is a lot to learn!
# Even after you master everything on this list, I hope you’ll keep ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0119e6d1-2de8-4477-b9d3-e6d98a5de8b8.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 692e1d27-12f8-4880-84a6-d7110099208a.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 354d28e9-55db-4d4a-9e35-a36b9bddb07d.
# > Parent node text: PAGE 22Over the course of a career, you’re likely to work on projects in succession, each growing...
#
# > Merging 1 nodes into parent node.
# > Parent node id

# > Parent node text: PAGE 38Before we dive into the final chapter of this book, I’d like to address the serious matter...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 11e81cf4-4a17-47eb-b798-c4301e2578d5.
# > Parent node text: PAGE 37Overcoming Imposter
# SyndromeCHAPTER 11
#
# > Merging 1 nodes into parent node.
# > Parent node id: 0119e6d1-2de8-4477-b9d3-e6d98a5de8b8.
# > Parent node text: PAGE 3Table of
# ContentsIntroduction: Coding AI is the New Literacy.
# Chapter 1: Three Steps to Ca...
#
# > Merging 1 nodes into parent node.
# > Parent node id: cb46e04d-5a7e-442c-ba35-f2f947824088.
# > Parent node text: PAGE 39My three-year-old daughter (who can barely count to 12) regularly tries to teach things to...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8a33cb0d-f0a5-4397-be98-ecde20d50e0b.
# > Parent node text: PAGE 7These phases apply in a wide
# range of professions, but AI
# involves unique elements.
# For e...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 32217df0-c34e-48d1-997d-d16dd91e7e43.
# > Parent node text: PAGE 4Coding AI Is the New Literacy
# Today we take it for granted that many people know how to rea...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ee03cd7c-146f-47e3-a043-7f362334f9d9.
# > Parent node text: PAGE 35Keys to Building a Career in AI CHAPTER 10
# The path to career success in AI is more comple...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 692e1d27-12f8-4880-84a6-d7110099208a.
# > Parent node text: PAGE 36Keys to Building a Career in AI CHAPTER 10
# Of all the steps in building a career, this
# on...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8ce93215-06bf-4941-984b-04e5d94ad3cd.
# > Parent node text: PAGE 33Choose who to work with. It’s tempting to take a position because of the projects you’ll w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: e4c1c474-53d9-4c64-ac6d-9514b90cc3da.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: e2153647-6afb-465d-80d0-c29dda9d3b14.
# > Parent node text: PAGE 18It goes without saying that we should only work on projects that are responsible, ethical,...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 61b4d915-8ae8-4253-a5d0-39060d268604.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...

# %%
from trulens_eval import Tru

Tru().get_leaderboard(app_ids=[])
# Out:
#         Context Relevance  Groundedness  Answer Relevance    latency  \
# app_id
# app_0            0.411594      0.666092          0.986957  12.916667
#
#         total_cost
# app_id
# app_0     0.003681

# %%
Tru().run_dashboard()
# Out:
# Starting dashboard ...
# Accordion(children=(VBox(children=(VBox(children=(Label(value='STDOUT'), Output())), VBox(children=(Label(valu…
# Dashboard started at https://s172-31-15-23p50257.lab-aws-production.deeplearning.ai/ .
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %% [markdown]
# ### Three layers

# %%
auto_merging_index_1 = build_automerging_index(
    documents,
    llm=OpenAI(model="gpt-3.5-turbo", temperature=0.1),
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="merging_index_1",
    chunk_sizes=[2048,512,128],
)

# %%
auto_merging_engine_1 = get_automerging_query_engine(
    auto_merging_index_1,
    similarity_top_k=12,
    rerank_top_n=6,
)

# %%
tru_recorder = get_prebuilt_trulens_recorder(
    auto_merging_engine_1,
    app_id ='app_1'
)
# Out:
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input response will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input source will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .

# %%
run_evals(eval_questions, tru_recorder, auto_merging_engine_1)
# Out:
# > Merging 4 nodes into parent node.
# > Parent node id: 876e3a03-3bbc-490a-bce3-e10f31f4e3d3.
# > Parent node text: PAGE 26If you’re considering a role switch, a startup can be an easier place to do it than a big ...
#
# > Merging 5 nodes into parent node.
# > Parent node id: 6f7d6a6c-5535-48d2-85c8-7339be59d602.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 17797313-0085-411f-85d2-f9df764b534c.
# > Parent node text: PAGE 26If you’re considering a role switch, a startup can be an easier place to do it than a big ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 83737dd7-0455-4b4f-afbe-c86e7b644ea5.
# > Parent node text: PAGE 25Finding a job has a few predictable steps that include selecting the companies to which yo...
#
# > Merging 5 nodes into parent node.
# > Parent node id: a6bed6e2-dae2-40ea-a233-87695745fd13.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 2eb34216-7214-4171-a105-deef6b52e016.
# > Parent node text: PAGE 27There’s a lot we don’t know about the future: When will we cure Alzheimer’s disease? Who w...
#
# > Merging 4 nodes into parent node.
# > Parent node id: f4f794ce-d87c-40ea-911c-5dac17d06444.
# > Parent node text: PAGE 20Working on projects requires making tough choices about what to build and how to go
# about...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 2a27106b-9b8c-4c0d-9d7a-4e515ed979af.
# > Parent node text: But when committing to a direction means making a costly investment or entering a one-
# way door  ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 43ac077e-a7c0-4e28-a89a-c2de99bc2449.
# > Parent node text: PAGE 20Working on projects requires making tough choices about what to build and how to go
# about...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 6b079bc7-a51c-4202-86bf-3f7de342a55a.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 1fe47f1f-26a6-49bb-8631-7b2011b2c13a.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 7be77328-2ef9-4203-ad30-927c58a33f90.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: ca9514c1-6ff3-4894-9c5e-3cb6b9c8465c.
# > Parent node text: PAGE 17Finding Projects that
# Complement Your
# Career GoalsCHAPTER 5
# PROJECTS
#
# > Merging 4 nodes into parent node.
# > Parent node id: 632255b0-a4ad-4925-ac98-2a77efb688c9.
# > Parent node text: PAGE 9In the previous chapter, I introduced three key steps for building a career in AI: learning...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 060bed93-0144-4369-952e-9cdf90728b23.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 4ec0df25-48df-4eb1-9dee-138700eb945c.
# > Parent node text: I’ve found EDA particularly
# useful in data-centric AI development, where analyzing errors and ga...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 47082426-2e69-49a4-8c4f-350a99ebb2a1.
# > Parent node text: PAGE 9In the previous chapter, I introduced three key steps for building a career in AI: learning...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 8ff6a4ec-acce-49d4-8027-6fd80c33f0d6.
# > Parent node text: PAGE 13Should you Learn Math to Get a Job in AI? CHAPTER 3
# Is math a foundational skill for AI? I...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 24b8a0e6-e0a1-495c-ba3f-61fc3c178164.
# > Parent node text: PAGE 8Learning Technical
# Skills for a Promising
# AI CareerCHAPTER 2
# LEARNING
#
# > Merging 1 nodes into parent node.
# > Parent node id: 25faec81-c1ee-4c76-bb7e-5ace658cf7bb.
# > Parent node text: PAGE 8Learning Technical
# Skills for a Promising
# AI CareerCHAPTER 2
# LEARNING
#
# > Merging 4 nodes into parent node.
# > Parent node id: d788d908-e198-440a-8661-bf091623e185.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 4545fef8-644e-4047-88d3-55b1b6c36672.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 2 nodes into parent node.
# > Parent node id: 6b079bc7-a51c-4202-86bf-3f7de342a55a.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 7be77328-2ef9-4203-ad30-927c58a33f90.
# > Parent node text: PAGE 6The rapid rise of AI has led to a rapid rise in AI jobs, and many people are building excit...
#
# > Merging 5 nodes into parent node.
# > Parent node id: d788d908-e198-440a-8661-bf091623e185.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: 4545fef8-644e-4047-88d3-55b1b6c36672.
# > Parent node text: PAGE 29If you’re preparing to switch roles (say, taking a job as a machine learning engineer for ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: a2bb00af-0e55-4db0-b832-9236d6cb56bb.
# > Parent node text: PAGE 28Using Informational
# Interviews to Find
# the Right JobCHAPTER 8
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 261948eb-853a-45dc-a2aa-c5a3ee6b0d43.
# > Parent node text: PAGE 24A Simple Framework
# for Starting Your AI
# Job SearchCHAPTER 7
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: e5fabb17-585c-440c-9978-52009a98b718.
# > Parent node text: PAGE 31Finding the Right
# AI Job for YouCHAPTER 9
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: c14674f2-27cb-4909-a4c3-fe4d1fb3c59d.
# > Parent node text: PAGE 28Using Informational
# Interviews to Find
# the Right JobCHAPTER 8
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: 5577cc89-7802-44c4-9c47-c9b5c5a9e4c0.
# > Parent node text: PAGE 24A Simple Framework
# for Starting Your AI
# Job SearchCHAPTER 7
# JOBS
#
# > Merging 1 nodes into parent node.
# > Parent node id: c2459ac4-7954-4195-a88b-679139689461.
# > Parent node text: PAGE 31Finding the Right
# AI Job for YouCHAPTER 9
# JOBS
#
# > Merging 4 nodes into parent node.
# > Parent node id: e26fc021-cf7e-4fd9-ba85-5820c79ed082.
# > Parent node text: PAGE 23Each project is only one step on a longer journey, hopefully one that has a positive impac...
#
# > Merging 2 nodes into parent node.
# > Parent node id: